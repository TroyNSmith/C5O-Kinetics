# %%
import mol

mol.intra_proton_transfer("[O]OCCCC1CO1", 15, 0)
# Out:
# Succeeded with 2.1499999999999995
# [14:04:44]
#
# ****
# Invariant Violation
#
# Violation occurred on line 57 in file /home/conda/feedstock_root/build_artifacts/rdkit-meta_1753546494515/work/Code/DistGeom/DistGeomUtils.cpp
# Failed Expression: ub >= lb
# ----------
# Stacktrace:
#  0# Invar::Invariant::toString[abi:cxx11]() const in /home/tns97255/C5O-Kinetics/.pixi/envs/default/lib/python3.12/site-packages/rdkit/../../../libRDKitRDGeneral.so.1
#  1# Invar::operator<<(std::ostream&, Invar::Invariant const&) in /home/tns97255/C5O-Kinetics/.pixi/envs/default/lib/python3.12/site-packages/rdkit/../../../libRDKitRDGeneral.so.1
# ...
